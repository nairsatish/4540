# %% [markdown]
# <a href="https://colab.research.google.com/github/nairsatish/4540/blob/master/XOR_FCN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

rng = np.random.RandomState(0)
X = rng.randn(1000, 2)
Y = np.logical_xor(X[:,0] > 0, X[:,1] > 0).astype(int)

c1 = X[np.nonzero(Y)[0]]
c2 = X[np.nonzero(Y == 0)[0]]

colors = ['red', 'blue']

plt.plot(c1[:,0], c1[:,1], 'ro', label='class 1')
plt.plot(c2[:,0], c2[:,1], 'bo', label='class 2')

plt.title('XOR') 
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

batch_size=8

training_data = DataLoader(TensorDataset(torch.Tensor(X[:750,:]), torch.tensor(Y[:750], dtype=torch.long)), shuffle=True, batch_size=batch_size)
validation_data = DataLoader(TensorDataset(torch.Tensor(X[750:,:]), torch.tensor(Y[750:], dtype=torch.long)), batch_size=batch_size)

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.activation = nn.ReLU()
        self.first_hidden = nn.Linear(2, 10)
        self.second_hidden = nn.Linear(10, 5)
        self.output = nn.Linear(5, 2)

    def forward(self, x):
        x = self.activation(self.first_hidden(x))
        x = self.activation(self.second_hidden(x))
        x = self.output(x)
        return x

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cuda device
# NeuralNetwork(
#   (activation): ReLU()
#   (first_hidden): Linear(in_features=2, out_features=10, bias=True)
#   (second_hidden): Linear(in_features=10, out_features=5, bias=True)
#   (output): Linear(in_features=5, out_features=2, bias=True)
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(training_data, model, loss_fn, optimizer)
    test(validation_data, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.667373  [    0/  750]
# Test Error:
#  Accuracy: 50.8%, Avg loss: 0.700634
#
# Epoch 2
# -------------------------------
# loss: 0.689445  [    0/  750]
# Test Error:
#  Accuracy: 58.8%, Avg loss: 0.682737
#
# Epoch 3
# -------------------------------
# loss: 0.676599  [    0/  750]
# Test Error:
#  Accuracy: 61.6%, Avg loss: 0.671986
#
# Epoch 4
# -------------------------------
# loss: 0.657963  [    0/  750]
# Test Error:
#  Accuracy: 66.8%, Avg loss: 0.663867
#
# Epoch 5
# -------------------------------
# loss: 0.672351  [    0/  750]
# Test Error:
#  Accuracy: 69.6%, Avg loss: 0.654531
#
# Epoch 6
# -------------------------------
# loss: 0.667586  [    0/  750]
# Test Error:
#  Accuracy: 68.0%, Avg loss: 0.647303
#
# Epoch 7
# -------------------------------
# loss: 0.709489  [    0/  750]
# Test Error:
#  Accuracy: 69.2%, Avg loss: 0.638174
#
# Epoch 8
# -------------------------------
# loss: 0.527226  [    0/  750]
# Test Error:
#  Accuracy: 69.2%, Avg loss: 0.631028
#
# Epoch 9
# -------------------------------
# loss: 0.617402  [    0/  750]
# Test Error:
#  Accuracy: 69.6%, Avg loss: 0.620099
#
# Epoch 10
# -------------------------------
# loss: 0.671341  [    0/  750]
# Test Error:
#  Accuracy: 71.2%, Avg loss: 0.609088
#
# Epoch 11
# -------------------------------
# loss: 0.519672  [    0/  750]
# Test Error:
#  Accuracy: 71.2%, Avg loss: 0.599401
#
# Epoch 12
# -------------------------------
# loss: 0.544797  [    0/  750]
# Test Error:
#  Accuracy: 70.0%, Avg loss: 0.588316
#
# Epoch 13
# -------------------------------
# loss: 0.708007  [    0/  750]
# Test Error:
#  Accuracy: 70.0%, Avg loss: 0.579917
#
# Epoch 14
# -------------------------------
# loss: 0.526377  [    0/  750]
# Test Error:
#  Accuracy: 70.4%, Avg loss: 0.570735
#
# Epoch 15
# -------------------------------
# loss: 0.501482  [    0/  750]
# Test Error:
#  Accuracy: 70.8%, Avg loss: 0.564690
#
# Epoch 16
# -------------------------------
# loss: 0.519332  [    0/  750]
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.555114
#
# Epoch 17
# -------------------------------
# loss: 0.751391  [    0/  750]
# Test Error:
#  Accuracy: 71.6%, Avg loss: 0.547314
#
# Epoch 18
# -------------------------------
# loss: 0.352790  [    0/  750]
# Test Error:
#  Accuracy: 71.2%, Avg loss: 0.543385
#
# Epoch 19
# -------------------------------
# loss: 0.395866  [    0/  750]
# Test Error:
#  Accuracy: 73.2%, Avg loss: 0.535536
#
# Epoch 20
# -------------------------------
# loss: 0.518282  [    0/  750]
# Test Error:
#  Accuracy: 73.2%, Avg loss: 0.529743
#
# Epoch 21
# -------------------------------
# loss: 0.266865  [    0/  750]
# Test Error:
#  Accuracy: 73.6%, Avg loss: 0.521111
#
# Epoch 22
# -------------------------------
# loss: 0.310059  [    0/  750]
# Test Error:
#  Accuracy: 74.4%, Avg loss: 0.514084
#
# Epoch 23
# -------------------------------
# loss: 0.477076  [    0/  750]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.503902
#
# Epoch 24
# -------------------------------
# loss: 0.349187  [    0/  750]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.499822
#
# Epoch 25
# -------------------------------
# loss: 0.421837  [    0/  750]
# Test Error:
#  Accuracy: 77.2%, Avg loss: 0.484974
#
# Epoch 26
# -------------------------------
# loss: 0.357997  [    0/  750]
# Test Error:
#  Accuracy: 79.2%, Avg loss: 0.473060
#
# Epoch 27
# -------------------------------
# loss: 0.598668  [    0/  750]
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.455060
#
# Epoch 28
# -------------------------------
# loss: 0.366837  [    0/  750]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.437634
#
# Epoch 29
# -------------------------------
# loss: 0.144424  [    0/  750]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.416791
#
# Epoch 30
# -------------------------------
# loss: 0.231060  [    0/  750]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.399719
#
# Epoch 31
# -------------------------------
# loss: 0.466955  [    0/  750]
# Test Error:
#  Accuracy: 84.8%, Avg loss: 0.375359
#
# Epoch 32
# -------------------------------
# loss: 0.221816  [    0/  750]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.356437
#
# Epoch 33
# -------------------------------
# loss: 0.209584  [    0/  750]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.341861
#
# Epoch 34
# -------------------------------
# loss: 0.445148  [    0/  750]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.323010
#
# Epoch 35
# -------------------------------
# loss: 0.290488  [    0/  750]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.311511
#
# Epoch 36
# -------------------------------
# loss: 0.187182  [    0/  750]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.290303
#
# Epoch 37
# -------------------------------
# loss: 0.144776  [    0/  750]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.280411
#
# Epoch 38
# -------------------------------
# loss: 0.102567  [    0/  750]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.262409
#
# Epoch 39
# -------------------------------
# loss: 0.226329  [    0/  750]
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.245619
#
# Epoch 40
# -------------------------------
# loss: 0.143077  [    0/  750]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.237181
#
# Epoch 41
# -------------------------------
# loss: 0.093631  [    0/  750]
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.225232
#
# Epoch 42
# -------------------------------
# loss: 0.061685  [    0/  750]
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.213957
#
# Epoch 43
# -------------------------------
# loss: 0.088027  [    0/  750]
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.203567
#
# Epoch 44
# -------------------------------
# loss: 0.197580  [    0/  750]
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.201906
#
# Epoch 45
# -------------------------------
# loss: 0.103095  [    0/  750]
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.188577
#
# Epoch 46
# -------------------------------
# loss: 0.227917  [    0/  750]
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.188691
#
# Epoch 47
# -------------------------------
# loss: 0.127669  [    0/  750]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.181184
#
# Epoch 48
# -------------------------------
# loss: 0.015163  [    0/  750]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.175343
#
# Epoch 49
# -------------------------------
# loss: 0.116959  [    0/  750]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.165545
#
# Epoch 50
# -------------------------------
# loss: 0.152599  [    0/  750]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.162683
#
# Epoch 51
# -------------------------------
# loss: 0.032719  [    0/  750]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.161358
#
# Epoch 52
# -------------------------------
# loss: 0.078084  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.154438
#
# Epoch 53
# -------------------------------
# loss: 0.038233  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.153037
#
# Epoch 54
# -------------------------------
# loss: 0.014122  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.151295
#
# Epoch 55
# -------------------------------
# loss: 0.197271  [    0/  750]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.146073
#
# Epoch 56
# -------------------------------
# loss: 0.060550  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.147340
#
# Epoch 57
# -------------------------------
# loss: 0.071357  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.141184
#
# Epoch 58
# -------------------------------
# loss: 0.202870  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.140183
#
# Epoch 59
# -------------------------------
# loss: 0.197841  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.134111
#
# Epoch 60
# -------------------------------
# loss: 0.158078  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.131091
#
# Epoch 61
# -------------------------------
# loss: 0.134516  [    0/  750]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.131465
#
# Epoch 62
# -------------------------------
# loss: 0.067664  [    0/  750]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.127758
#
# Epoch 63
# -------------------------------
# loss: 0.002532  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.124909
#
# Epoch 64
# -------------------------------
# loss: 0.041672  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.121785
#
# Epoch 65
# -------------------------------
# loss: 0.005966  [    0/  750]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.128591
#
# Epoch 66
# -------------------------------
# loss: 0.110285  [    0/  750]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.132242
#
# Epoch 67
# -------------------------------
# loss: 0.012319  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.124119
#
# Epoch 68
# -------------------------------
# loss: 0.063539  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.118358
#
# Epoch 69
# -------------------------------
# loss: 0.040464  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.120657
#
# Epoch 70
# -------------------------------
# loss: 0.169849  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.122921
#
# Epoch 71
# -------------------------------
# loss: 0.007510  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.117211
#
# Epoch 72
# -------------------------------
# loss: 0.033240  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.115569
#
# Epoch 73
# -------------------------------
# loss: 0.040409  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.109856
#
# Epoch 74
# -------------------------------
# loss: 0.095975  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.111845
#
# Epoch 75
# -------------------------------
# loss: 0.048902  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.112063
#
# Epoch 76
# -------------------------------
# loss: 0.039761  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.108685
#
# Epoch 77
# -------------------------------
# loss: 0.128826  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.106805
#
# Epoch 78
# -------------------------------
# loss: 0.029573  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.108699
#
# Epoch 79
# -------------------------------
# loss: 0.029593  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.105351
#
# Epoch 80
# -------------------------------
# loss: 0.123956  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.114801
#
# Epoch 81
# -------------------------------
# loss: 0.021783  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.110575
#
# Epoch 82
# -------------------------------
# loss: 0.111579  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.105355
#
# Epoch 83
# -------------------------------
# loss: 0.021354  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.110022
#
# Epoch 84
# -------------------------------
# loss: 0.026870  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.101489
#
# Epoch 85
# -------------------------------
# loss: 0.165358  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.098054
#
# Epoch 86
# -------------------------------
# loss: 0.060122  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.096647
#
# Epoch 87
# -------------------------------
# loss: 0.053992  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.104181
#
# Epoch 88
# -------------------------------
# loss: 0.064281  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.099655
#
# Epoch 89
# -------------------------------
# loss: 0.003903  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.094194
#
# Epoch 90
# -------------------------------
# loss: 0.052089  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.094629
#
# Epoch 91
# -------------------------------
# loss: 0.031061  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.098068
#
# Epoch 92
# -------------------------------
# loss: 0.195426  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.101920
#
# Epoch 93
# -------------------------------
# loss: 0.082634  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.090942
#
# Epoch 94
# -------------------------------
# loss: 0.073245  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.091976
#
# Epoch 95
# -------------------------------
# loss: 0.021134  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.091159
#
# Epoch 96
# -------------------------------
# loss: 0.026854  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.090735
#
# Epoch 97
# -------------------------------
# loss: 0.056735  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.085393
#
# Epoch 98
# -------------------------------
# loss: 0.033875  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.087145
#
# Epoch 99
# -------------------------------
# loss: 0.079577  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.089058
#
# Epoch 100
# -------------------------------
# loss: 0.075338  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.085220
#
# Done!

# %%
def predict(x):
    #Convert into numpy element to tensor
    x = torch.from_numpy(x).type(torch.FloatTensor).to(device)
    #Predict and return ans
    ans = torch.argmax(model(x), dim=1)
    return ans.to('cpu').detach().numpy()

# %%
# Helper function to plot a decision boundary.
def plot_decision_boundary(pred_func,X,y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx,yy=np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.title('XOR')
    plt.xlabel('x axis')
    plt.ylabel('y axis')
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
#     plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.binary)
    plt.plot(c1[:,0], c1[:,1], 'ko', label='class 1')
    plt.plot(c2[:,0], c2[:,1], 'wo', label='class 2')
    plt.legend()

# %%
plot_decision_boundary(lambda x : predict(x) ,X, Y)
